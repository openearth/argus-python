# %%
import numpy as np
from argus2.catalog import html_parser
import setuptools
import random
import argus2
import re
import urllib2
import datetime
import time
import base64
import pickle

# %%
# parameters
stations = ['jvspeijk','egmond','kijkduin','zandmotor']
datelims = [2012,'November',2013,'October']
picpercam = 4
daytime = True
sunrise = False
sunset = False
sunrisetime = 8
sunsettime = 15
summer = True
winter = False
summermonths = range(5,10)
wintermonths = range(1,5)
wintermonths.extend(range(10,13))

# %%
years = range(datelims[0],datelims[2]+1)
images = []

for i in range(len(stations)):
    
    cameras = argus2.catalog.html_parser.get_station_cameras(stations[i],datelims[2])
    
    months = []
    for j in years:
        ymonths = argus2.catalog.html_parser.get_station_months(stations[i],str(j))
        if ymonths:
            if (j == datelims[0]) & (j != datelims[2]):
                months.append([x for x in ymonths if time.strptime(x,'%B') >= time.strptime(datelims[1],'%B')])
            elif (j != datelims[0]) & (j == datelims[2]):
                months.append([x for x in ymonths if time.strptime(x,'%B') <= time.strptime(datelims[3],'%B')])
            elif (j == datelims[0]) & (j == datelims[2]):
                months.append([x for x in ymonths if (time.strptime(x,'%B') >= time.strptime(datelims[1],'%B')) & (time.strptime(x,'%B') <= time.strptime(datelims[3],'%B'))])
            else:
                months.append(ymonths)
        else:
            months.append([])
            
    if not summer:          # Remove summer months from list
        summon = []
        for j in summermonths:
            timobj = datetime.date(2013,j,1)
            summon.append(timobj.strftime('%B'))
        for j in range(len(months)):
            for k in range(len(summon)):
                if summon[k] in months[j]:
                    months[j].remove(summon[k])
                    
    if not winter:        # Remove winter months from list
        winmon = []
        for j in wintermonths:
            timobj = datetime.date(2013,j,1)
            winmon.append(timobj.strftime('%B'))        
        for j in range(len(months)):
            for k in range(len(winmon)):
                if winmon[k] in months[j]:
                    months[j].remove(winmon[k])
                   
    days = []
    for k in range(len(months)):   # This is the number of years..
        if not months[k]:
            continue
            
        for l in range(len(months[k])):     # This is the number of months..
            days.extend([time.strptime(x + '_' + months[k][l] + '_' + str(years[k]),'%a %d_%B_%Y') for x in argus2.catalog.html_parser.get_station_days(stations[i],years[k],months[k][l])])
        random.shuffle(days)
        
    count = 0
        
    for j in range(len(cameras)):
        for l in range(0,picpercam):
            while True:
                dayimsall = argus2.catalog.html_parser.get_station_images(stations[i],str(years[k]),time.strftime('%B',days[count]),time.strftime('%d',days[count]))
                count = count + 1
                
                if not dayimsall:
                    continue
                 
                dayims = []
                dayims.extend([x for x in dayimsall if ('.c' + cameras[j] + '.') in x])
                    
                if not dayims:
                    continue
                        
                if (not sunrise) | (not sunset) | (not daytime):
                    imtimes = []
                    regexp = re.compile('_(\d{2}_\d{2}_\d{2})')
                    imtimes.extend([time.strptime(regexp.findall(x)[0],'%H_%M_%S') for x in dayims])
                    if not sunrise:
                        imind = [imtimes.index(x) for x in imtimes if x.tm_hour < sunrisetime]
                        imind.reverse()
                        [dayims.pop(x) for x in imind]
                        [imtimes.pop(x) for x in imind]
                    if not sunset:
                        imind = [imtimes.index(x) for x in imtimes if x.tm_hour >= sunsettime]
                        imind.reverse()
                        [dayims.pop(x) for x in imind]
                        [imtimes.pop(x) for x in imind]
                    if not daytime:
                        imind = [imtimes.index(x) for x in imtimes if (x.tm_hour >= sunrisetime) & (x.tm_hour < sunsettime)]
                        imind.reverse()
                        [dayims.pop(x) for x in imind]
                        [imtimes.pop(x) for x in imind]
                    if not dayims:
                        continue
                images.extend(random.sample(dayims,1))
                break

# %%
images
# Out:
# ['http://argus-data.wldelft.nl/sites/jvspeijk/2013/c1/192_Jul.11/1373551201.Thu.Jul.11_14_00_01.GMT.2013.jvspeijk.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c1/140_May.20/1369042201.Mon.May.20_09_30_01.GMT.2013.jvspeijk.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c1/142_May.22/1369229402.Wed.May.22_13_30_02.GMT.2013.jvspeijk.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c1/147_May.27/1369657802.Mon.May.27_12_30_02.GMT.2013.jvspeijk.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c2/197_Jul.16/1373972403.Tue.Jul.16_11_00_03.GMT.2013.jvspeijk.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c2/218_Aug.06/1375783202.Tue.Aug.06_10_00_02.GMT.2013.jvspeijk.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c2/271_Sep.28/1380375002.Sat.Sep.28_13_30_02.GMT.2013.jvspeijk.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c2/226_Aug.14/1376488803.Wed.Aug.14_14_00_03.GMT.2013.jvspeijk.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c3/213_Aug.01/1375356603.Thu.Aug.01_11_30_03.GMT.2013.jvspeijk.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c3/221_Aug.09/1376049603.Fri.Aug.09_12_00_03.GMT.2013.jvspeijk.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c3/211_Jul.30/1375176603.Tue.Jul.30_09_30_03.GMT.2013.jvspeijk.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c3/255_Sep.12/1378990803.Thu.Sep.12_13_00_03.GMT.2013.jvspeijk.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c4/270_Sep.27/1380272404.Fri.Sep.27_09_00_04.GMT.2013.jvspeijk.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c4/175_Jun.24/1372069804.Mon.Jun.24_10_30_04.GMT.2013.jvspeijk.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c4/236_Aug.24/1377347404.Sat.Aug.24_12_30_04.GMT.2013.jvspeijk.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c4/171_Jun.20/1371738605.Thu.Jun.20_14_30_05.GMT.2013.jvspeijk.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c5/238_Aug.26/1377513006.Mon.Aug.26_10_30_06.GMT.2013.jvspeijk.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c5/172_Jun.21/1371801605.Fri.Jun.21_08_00_05.GMT.2013.jvspeijk.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c5/235_Aug.23/1377244806.Fri.Aug.23_08_00_06.GMT.2013.jvspeijk.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/jvspeijk/2013/c5/205_Jul.24/1374667206.Wed.Jul.24_12_00_06.GMT.2013.jvspeijk.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c1/271_Sep.28/1380355202.Sat.Sep.28_08_00_02.GMT.2013.egmond.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c1/225_Aug.13/1376391602.Tue.Aug.13_11_00_02.GMT.2013.egmond.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c1/170_Jun.19/1371650402.Wed.Jun.19_14_00_02.GMT.2013.egmond.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c1/165_Jun.14/1371209402.Fri.Jun.14_11_30_02.GMT.2013.egmond.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c2/147_May.27/1369643403.Mon.May.27_08_30_03.GMT.2013.egmond.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c2/244_Sep.01/1378045803.Sun.Sep.01_14_30_03.GMT.2013.egmond.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c2/233_Aug.21/1377095402.Wed.Aug.21_14_30_02.GMT.2013.egmond.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c2/121_May.01/1367407802.Wed.May.01_11_30_02.GMT.2013.egmond.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c3/142_May.22/1369225803.Wed.May.22_12_30_03.GMT.2013.egmond.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c3/151_May.31/1369996203.Fri.May.31_10_30_03.GMT.2013.egmond.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c3/251_Sep.08/1378645203.Sun.Sep.08_13_00_03.GMT.2013.egmond.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c3/254_Sep.11/1378893604.Wed.Sep.11_10_00_04.GMT.2013.egmond.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c4/148_May.28/1369747805.Tue.May.28_13_30_05.GMT.2013.egmond.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c4/184_Jul.03/1372860005.Wed.Jul.03_14_00_05.GMT.2013.egmond.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c4/198_Jul.17/1374057004.Wed.Jul.17_10_30_04.GMT.2013.egmond.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c4/127_May.07/1367933404.Tue.May.07_13_30_04.GMT.2013.egmond.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c5/255_Sep.12/1378978205.Thu.Sep.12_09_30_05.GMT.2013.egmond.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c5/129_May.09/1368104406.Thu.May.09_13_00_06.GMT.2013.egmond.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c5/156_Jun.05/1370426405.Wed.Jun.05_10_00_05.GMT.2013.egmond.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/egmond/2013/c5/221_Aug.09/1376056806.Fri.Aug.09_14_00_06.GMT.2013.egmond.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c1/255_Sep.12/1378985401.Thu.Sep.12_11_30_01.UTC.2013.kijkduin.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c1/260_Sep.17/1379426402.Tue.Sep.17_14_00_02.UTC.2013.kijkduin.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c1/127_May.07/1367924401.Tue.May.07_11_00_01.UTC.2013.kijkduin.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c1/125_May.05/1367746202.Sun.May.05_09_30_02.UTC.2013.kijkduin.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c2/171_Jun.20/1371724202.Thu.Jun.20_10_30_02.UTC.2013.kijkduin.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c2/225_Aug.13/1376388002.Tue.Aug.13_10_00_02.UTC.2013.kijkduin.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c2/233_Aug.21/1377082803.Wed.Aug.21_11_00_03.UTC.2013.kijkduin.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c2/236_Aug.24/1377354602.Sat.Aug.24_14_30_02.UTC.2013.kijkduin.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c3/271_Sep.28/1380375003.Sat.Sep.28_13_30_03.UTC.2013.kijkduin.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c3/216_Aug.04/1375617604.Sun.Aug.04_12_00_04.UTC.2013.kijkduin.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c3/207_Jul.26/1374836404.Fri.Jul.26_11_00_04.UTC.2013.kijkduin.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c3/188_Jul.07/1373185803.Sun.Jul.07_08_30_03.UTC.2013.kijkduin.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c4/241_Aug.29/1377786604.Thu.Aug.29_14_30_04.UTC.2013.kijkduin.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c4/122_May.02/1367488805.Thu.May.02_10_00_05.UTC.2013.kijkduin.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c4/182_Jul.01/1372680004.Mon.Jul.01_12_00_04.UTC.2013.kijkduin.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c4/160_Jun.09/1370777404.Sun.Jun.09_11_30_04.UTC.2013.kijkduin.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c5/179_Jun.28/1372413605.Fri.Jun.28_10_00_05.UTC.2013.kijkduin.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c5/247_Sep.04/1378288805.Wed.Sep.04_10_00_05.UTC.2013.kijkduin.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c5/264_Sep.21/1379750405.Sat.Sep.21_08_00_05.UTC.2013.kijkduin.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c5/263_Sep.20/1379682005.Fri.Sep.20_13_00_05.UTC.2013.kijkduin.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c6/143_May.23/1369314006.Thu.May.23_13_00_06.UTC.2013.kijkduin.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c6/174_Jun.23/1371981606.Sun.Jun.23_10_00_06.UTC.2013.kijkduin.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c6/222_Aug.10/1376145006.Sat.Aug.10_14_30_06.UTC.2013.kijkduin.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/kijkduin/2013/c6/169_Jun.18/1371547807.Tue.Jun.18_09_30_07.UTC.2013.kijkduin.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c1/238_Aug.26/1377514801.Mon.Aug.26_11_00_01.UTC.2013.zandmotor.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c1/253_Sep.10/1378800001.Tue.Sep.10_08_00_01.UTC.2013.zandmotor.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c1/160_Jun.09/1370775601.Sun.Jun.09_11_00_01.UTC.2013.zandmotor.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c1/157_Jun.06/1370507401.Thu.Jun.06_08_30_01.UTC.2013.zandmotor.c1.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c2/254_Sep.11/1378899003.Wed.Sep.11_11_30_03.UTC.2013.zandmotor.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c2/167_Jun.16/1371393002.Sun.Jun.16_14_30_02.UTC.2013.zandmotor.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c2/182_Jul.01/1372669202.Mon.Jul.01_09_00_02.UTC.2013.zandmotor.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c2/236_Aug.24/1377331202.Sat.Aug.24_08_00_02.UTC.2013.zandmotor.c2.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c3/183_Jul.02/1372755603.Tue.Jul.02_09_00_03.UTC.2013.zandmotor.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c3/185_Jul.04/1372926603.Thu.Jul.04_08_30_03.UTC.2013.zandmotor.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c3/181_Jun.30/1372593603.Sun.Jun.30_12_00_03.UTC.2013.zandmotor.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c3/133_May.13/1368446403.Mon.May.13_12_00_03.UTC.2013.zandmotor.c3.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c4/205_Jul.24/1374658204.Wed.Jul.24_09_30_04.UTC.2013.zandmotor.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c4/169_Jun.18/1371560404.Tue.Jun.18_13_00_04.UTC.2013.zandmotor.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c4/226_Aug.14/1376487004.Wed.Aug.14_13_30_04.UTC.2013.zandmotor.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c4/213_Aug.01/1375344004.Thu.Aug.01_08_00_04.UTC.2013.zandmotor.c4.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c5/186_Jul.05/1373020205.Fri.Jul.05_10_30_05.UTC.2013.zandmotor.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c5/256_Sep.13/1379066406.Fri.Sep.13_10_00_06.UTC.2013.zandmotor.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c5/196_Jul.15/1373889606.Mon.Jul.15_12_00_06.UTC.2013.zandmotor.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c5/263_Sep.20/1379682002.Fri.Sep.20_13_00_02.UTC.2013.zandmotor.c5.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c6/138_May.18/1368887406.Sat.May.18_14_30_06.UTC.2013.zandmotor.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c6/121_May.01/1367404206.Wed.May.01_10_30_06.UTC.2013.zandmotor.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c6/129_May.09/1368091807.Thu.May.09_09_30_07.UTC.2013.zandmotor.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c6/211_Jul.30/1375171206.Tue.Jul.30_08_00_06.UTC.2013.zandmotor.c6.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c7/241_Aug.29/1377783007.Thu.Aug.29_13_30_07.UTC.2013.zandmotor.c7.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c7/235_Aug.23/1377262808.Fri.Aug.23_13_00_08.UTC.2013.zandmotor.c7.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c7/221_Aug.09/1376049608.Fri.Aug.09_12_00_08.UTC.2013.zandmotor.c7.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c7/145_May.25/1369477807.Sat.May.25_10_30_07.UTC.2013.zandmotor.c7.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c8/242_Aug.30/1377862208.Fri.Aug.30_11_30_08.UTC.2013.zandmotor.c8.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c8/249_Sep.06/1378459808.Fri.Sep.06_09_30_08.UTC.2013.zandmotor.c8.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c8/246_Sep.03/1378206005.Tue.Sep.03_11_00_05.UTC.2013.zandmotor.c8.snap.jpg',
#  'http://argus-data.wldelft.nl/sites/zandmotor/2013/c8/134_May.14/1368522008.Tue.May.14_09_00_08.UTC.2013.zandmotor.c8.snap.jpg']

# %%
with open('images_new.txt','wb') as f:
    pickle.dump(images,f)

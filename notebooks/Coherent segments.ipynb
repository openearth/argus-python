# %%
import os
import cPickle as pickle
import matplotlib.pyplot as plt
from argus2.segmentation import postprocess

fpath = '../../argusgui/argusgui/datasets/argusnl_new'
# Out:
# /home/hoonhout/VirtualEnv/argusgui/lib/python2.7/site-packages/matplotlib/__init__.py:1141: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
for fname in os.listdir(fpath):
    if fname.endswith('.segments.pkl'):
        print fname
        
        with open(os.path.join(fpath,fname),'rb') as fp:
            seg = pickle.load(fp)
            
        seg['segments'] = postprocess.remove_disjoint(np.asarray(seg['segments']))
        
        with open(os.path.join(fpath,fname.replace('.segments.pkl','.cohsegments.pkl')),'wb') as fp:
            pickle.dump(seg,fp)
# Out:
# 1372926603.Thu.Jul.04_08_30_03.UTC.2013.zandmotor.c3.snap.segments.pkl

# %%
i1 = 1000
i2 = 1500

fig, axs = plt.subplots(1,3,figsize=(30,20))
axs[0].imshow(np.asarray(seg['segments'])[i1:i2,i1:i2],cmap='prism')
axs[1].imshow(seg_new[i1:i2,i1:i2],cmap='prism')
axs[2].imshow((np.abs(seg['segments']-seg_new) > 0)[i1:i2,i1:i2],cmap='binary')
